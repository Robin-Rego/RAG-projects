# %% [markdown]
# <a href="https://colab.research.google.com/github/Robin-Rego/RAG-projects/blob/main/RAG_WebpageProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install the packages
# !pip install langchain_community langchainhub langchain chromadb langchain-openai

# %%
from google.colab import userdata
import os
os.environ['OPENAI_API_KEY'] = userdata.get('OPENAI_API_KEY')
#

# %%
#Our data is a webpage=> we will use WebBaseLoader
from langchain_community.document_loaders import WebBaseLoader
# lets give multiple web paths
